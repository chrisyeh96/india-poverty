849, 0.60140986485972248, 0.63331991036682234, 0.67874741928287874, 0.67475477002477946, 0.71756453960314714, 0.74357380834143161, 0.75507883704637502, 0.75990386565228762], 'val': [0.0001140652428457469, 0.00052242018778572545, 0.00023884111099158401, 0.00068008770230740636, 0.0021027434610526468, 0.0039656468484936614, 0.00089897344876123646, 0.0012217938726315426, 0.0053518864949503846, 0.0072627901890386813, 0.0068282805286764047, 0.0084063489745169282, 0.0082873323352963546, 0.0033841653269305878, 0.016903564107491675, 0.0070946605580825455, 0.024109055680831569, 0.025096061244094758, 0.016940886524249136, 0.015240330181533476, 0.020516709192563144, 0.024510620481936102, 0.028101471051369103, 0.028999727120113138, 0.037180765144166884, 0.034025112810561531, 0.034167962766384515, 0.048300057268227496, 0.049338659640693047, 0.064962591017464197, 0.070521580368792511, 0.070913671225232011, 0.10254570250758833, 0.12290831470541991, 0.15808051244465945, 0.15421575674501151, 0.20798403295219708, 0.28613981001946137, 0.33037422484076573, 0.37927235784422736, 0.40432804458989463, 0.44509097788819973, 0.47088198935079273, 0.48686702230165468, 0.54159439681197985, 0.52213645161747602, 0.56125076301601773, 0.59062812336935133, 0.59812596787058425, 0.60642918578071625]}
l8_train_losses = np.load("/home/echartock03/models/l8_2015_losses_train_epochs_100_finetune_True.npy")
l8_val_losses = np.load("/home/echartock03/models/l8_2015_losses_val_epochs_100_finetune_True.npy")
s1_train_losses = np.load("/home/echartock03/models/s1_2015_losses_train_epochs_100_finetune_True.npy")
s1_val_losses = np.load("/home/echartock03/models/s1_2015_losses_val_epochs_100_finetune_True.npy")
l8_train_r2 = np.load("/home/echartock03/models/l8_2015_r2s_train_epochs_100_finetune_True.npy")
l8_val_r2 = np.load("/home/echartock03/models/l8_2015_r2s_val_epochs_100_finetune_True.npy")
s1_train_r2 = np.load("/home/echartock03/models/s1_2015_r2s_train_epochs_100_finetune_True.npy")
s1_val_r2 = np.load("/home/echartock03/models/s1_2015_r2s_val_epochs_100_finetune_True.npy")
l8_best_y_pred = np.load("/home/echartock03/models/l8_2015_bestypred_epochs_100_finetune_True.npy")
l8_best_y_true = np.load("/home/echartock03/models/l8_2015_bestytrue_epochs_100_finetune_True.npy")
s1_best_y_pred = np.load("/home/echartock03/models/s1_2015_bestypred_epochs_100_finetune_True.npy")
s1_best_y_true = np.load("/home/echartock03/models/s1_2015_bestytrue_epochs_100_finetune_True.npy")

# %%
#plt.figure(figsize=(16, 4))
#plt.subplot(1, 2, 1)
#plt.plot(l8_train_losses, label="train")
#plt.plot(l8_val_losses, label="val")
#plt.title("LandSat-8: Loss over epochs")
#plt.xlabel("Epochs")
#plt.legend()

#plt.subplot(1, 2, 2)
#plt.plot(np.array(rsq["train"]), label="train")
#plt.plot(np.array(rsq["val"]), label="val")
#plt.title("LandSat-8: $R^2$ over epochs")
#plt.xlabel("Epochs")
#plt.legend()

# %%
plt.figure(figsize=(12, 6))
plt.plot(l8_train_losses, label="train")
plt.plot(l8_val_losses, label="val")
plt.title("LandSat-8: Loss over epochs")
plt.xlabel("Epochs")
plt.legend()

# %%
plt.figure(figsize=(12, 6))
plt.plot(s1_train_losses, label="train")
plt.plot(s1_val_losses, label="val")
plt.title("Sentinel-1: Loss over epochs")
plt.xlabel("Epochs")
plt.legend()

# %%
plt.figure(figsize=(12, 6))
plt.plot(l8_train_r2, label="train")
plt.plot(l8_val_r2, label="val")
plt.title("LandSat-8: $R^2$ over epochs")
plt.xlabel("Epochs")
plt.legend()

# %%
plt.figure(figsize=(12, 6))
plt.plot(s1_train_r2, label="train")
plt.plot(s1_val_r2, label="val")
plt.title("Sentinel-1: $R^2$ over epochs")
plt.xlabel("Epochs")
plt.legend()

# %% [markdown]
# Sentinel-1

# %%
#rsq_train = np.array([ 0.00036457,  0.00198868,  0.0025317 ,  0.00413859,  0.00680634,
#        0.01026039,  0.00986789,  0.01242627,  0.01328416,  0.0158855 ,
#        0.02165581,  0.02110433,  0.02693423,  0.02825476,  0.03619453,
#        0.05297008])

#rsq_val = np.array([ 0.0002256 ,  0.00079412,  0.00543012,  0.00271057,  0.00895483,
#        0.01357055,  0.01058456,  0.01342562,  0.02081358,  0.02189011,
#        0.01893835,  0.01793572,  0.0138493 ,  0.03354341,  0.0349814 ,
#        0.04913074])

# %% [markdown]
# Predicted versus observed plot, log-log scale.

# %%
import seaborn as sns

# %%
fig = sns.jointplot(np.log(l8_best_y_true[np.logical_and(l8_best_y_true > 0, l8_best_y_pred > 0)]), 
                    np.log(l8_best_y_pred[np.logical_and(l8_best_y_true > 0, l8_best_y_pred > 0)]), 
                    kind="reg", size=8, marker=".")
fig.fig.set_size_inches((12, 8))
fig.ax_joint.set(ylabel="Log Predicted household expenditures [Taka]",
                 xlabel="Log Observed household expenditures [Taka]")
fig.ax_joint.set_title("Landsat8 Bangladesh: CNN predicted versus observed household expenditures", y=0.98);

# %%
fig = sns.jointplot(np.log(s1_best_y_true[np.logical_and(s1_best_y_true > 0, s1_best_y_pred > 0)]), 
                    np.log(s1_best_y_pred[np.logical_and(s1_best_y_true > 0, s1_best_y_pred > 0)]), 
                    kind="reg", size=8, marker=".")
fig.fig.set_size_inches((12, 8))
fig.ax_joint.set(ylabel="Log Predicted household expenditures [Taka]",
                 xlabel="Log Observed household expenditures [Taka]")
fig.ax_joint.set_title("Sentinel-1 Bangladesh: CNN predicted versus observed household expenditures", y=0.98);

# %%
fig = sns.jointplot(l8_best_y_true[np.logical_and(l8_best_y_true > 0, l8_best_y_pred > 0)], 
                    l8_best_y_pred[np.logical_and(l8_best_y_true > 0, l8_best_y_pred > 0)], 
                    kind="reg", size=8, marker=".")
fig.fig.set_size_inches((12, 8))
fig.ax_joint.set(ylabel="Predicted household expenditures [Taka]",
                 xlabel="Observed household expenditures [Taka]")
fig.ax_joint.set_title("Landsat8 Bangladesh: CNN predicted versus observed household expenditures", y=0.98);

# %%
fig = sns.jointplot(s1_best_y_true[np.logical_and(s1_best_y_true > 0, s1_best_y_pred > 0)], 
                    s1_best_y_pred[np.logical_and(s1_best_y_true > 0, s1_best_y_pred > 0)], 
                    kind="reg", size=8, marker=".")
fig.fig.set_size_inches((12, 8))
fig.ax_joint.set(ylabel="Predicted household expenditures [Taka]",
                 xlabel="Observed household expenditures [Taka]")
fig.ax_joint.set_title("Sentinel-1 Bangladesh: CNN predicted versus observed household expenditures", y=0.98);

# %% [markdown]
# Overfit plots

# %%
overfit_loss = [5093.643725585937, 4676.791882324219, 4363.685198974609, 4026.3490966796876, 3635.386120605469, 3144.7407836914062, 2718.168408203125, 2262.1926879882812, 2389.1361389160156, 1838.3451850891113, 1508.2943542480468, 1256.239453125, 1078.371971511841, 1088.3546905517578, 744.5476776123047, 533.3916725158691, 447.17305145263674, 580.2465515136719, 651.9711898803711, 565.3322830200195, 618.3406265258789, 319.81981296539306, 458.3225959777832, 386.1739990234375, 221.6473602294922, 525.6329475402832, 274.21998596191406, 331.52177448272704, 78.22542514801026, 559.9616733551026, 321.0832459449768, 458.70751152038576, 324.27373752593996, 344.92070751190187, 386.0312707424164, 259.264102935791, 312.43306822776793, 226.4518747329712, 146.21445360183716, 80.8284520149231, 169.7769953727722, 133.04582545757293, 123.95535125732422, 99.43965873718261, 112.88434047698975, 76.45847570896149, 32.95994358062744, 52.225943660736085, 86.60473518371582, 19.512587344646455]

# %%
overfit_rsq = [0.016946788464975226, 0.17159496094599463, 0.16779885488459834, 0.25736758624348022, 0.32707030428453121, 0.48144016200888395, 0.5087505202724939, 0.63711679741663518, 0.2413786618985195, 0.51002325360427869, 0.60458761255990268, 0.64152115654427833, 0.63581510215360826, 0.50665579162195118, 0.70854176020497517, 0.82782242225404945, 0.81638838271303293, 0.65206280888495127, 0.55183398890002433, 0.60618482222195058, 0.56410351152879734, 0.78048906206295743, 0.65339254303842442, 0.70857967926731469, 0.8289317441098536, 0.58253543955244191, 0.785161245144122, 0.73558766836351108, 0.93937164803952788, 0.54510039109648956, 0.73762882088637149, 0.62408792411893577, 0.73399041938198406, 0.71816453025073801, 0.68592356484512951, 0.79563904390655826, 0.77478182508307825, 0.84181879478164456, 0.90361120353706059, 0.93460725321408999, 0.87899759916471298, 0.89381626850772322, 0.90498797626795113, 0.93097062061121771, 0.91050365823019352, 0.94554556127726863, 0.9739899784378957, 0.9616086282022287, 0.93748497002162834, 0.9841263629025917]

# %%
plt.figure(figsize=(16, 4))
plt.subplot(1, 2, 1)
plt.plot(np.array(overfit_loss) / 4, label="train")
plt.title("LandSat-8 overfit: Loss over epochs")
plt.xlabel("Epochs")
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(np.array(overfit_rsq), label="train")
plt.title("LandSat-8 overfit: $R^2$ over epochs")
plt.xlabel("Epochs")
plt.legend()
